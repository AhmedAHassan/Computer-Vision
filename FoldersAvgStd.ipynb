# %%
import pandas as pd
import numpy as np
import cv2 as cv
import os
from scipy import stats
from PIL import Image
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# 'C:\\Users\\hp\\Videos\\Step1-fixedDistance_avg,std\\Folders\\2016-11-22-14-09-37-Joao_onlythermalthermal_image-txt'

# %% [markdown]
# Joao df for 100 files with four down scales and average for each row at each size

# %%
os.chdir(r"C:\Users\hp\Videos\Step1-fixedDistance_avg,std\Folders\2016-11-22-14-09-37-Joao_onlythermalthermal_image-txt")

# %%
joao_files = []  #Joao 

for idx,file in enumerate(os.listdir()):
    with open(file,encoding="utf8", errors='ignore')as f:
        text_file = np.loadtxt(f)
        
        cam_res1 = cv.resize(text_file, (191,144), interpolation = cv.INTER_NEAREST)
        cam_res1[cam_res1<32.0]=0
        cam_res1[cam_res1>37.0]=0
        #print(np.max(cam_res1), np.min(cam_res1[cam_res1 != 0 ]))
        
        
        cam_res2 = cv.resize(cam_res1, (95,72), interpolation = cv.INTER_NEAREST)
        cam_res3 = cv.resize(cam_res2, (32,24), interpolation = cv.INTER_NEAREST)
        #rint(np.max(cam_res3), np.min(cam_res3[cam_res3 != 0 ]))
        """"
        plt.imshow(text_file,cmap='jet')
        plt.show()
        plt.imshow(cam_res1,cmap='jet')
        plt.show()
        plt.imshow(cam_res2,cmap='jet')
        plt.show()
        plt.imshow(cam_res3,cmap='jet')
        plt.show()
        print()
        """
        
        joao_files.append({"file_name":file,
                              "AvgTemp(144,191)": np.average(cam_res1[cam_res1 != 0]),
                              "AvgTemp(72,95)": np.average(cam_res2[cam_res2 != 0]),
                              "AvgTemp(24,32)": np.average(cam_res3[cam_res3 != 0])})
        
    
    if idx == 99:
        break

# %%
df_joao = pd.DataFrame(joao_files, columns = ['file_name', "AvgTemp(144,191)","AvgTemp(72,95)","AvgTemp(24,32)"])

# %%
pd.set_option('max_rows', 99)
df_joao
# Out:
#                             file_name  AvgTemp(144,191)  AvgTemp(72,95)  \
# 0   thermal_20161122-14_09_37.471.txt  34.474038         34.458716
# 1   thermal_20161122-14_09_37.646.txt  34.454828         34.454174
# 2   thermal_20161122-14_09_37.718.txt  34.461408         34.456102
# 3   thermal_20161122-14_09_37.756.txt  34.474037         34.477656
# 4   thermal_20161122-14_09_37.791.txt  34.467482         34.465766
# ..                                ...        ...               ...
# 95  thermal_20161122-14_09_41.166.txt  34.523156         34.538530
# 96  thermal_20161122-14_09_41.201.txt  34.537173         34.535273
# 97  thermal_20161122-14_09_41.236.txt  34.550584         34.539750
# 98  thermal_20161122-14_09_41.276.txt  34.541973         34.515780
# 99  thermal_20161122-14_09_41.315.txt  34.537595         34.538959
#
#     AvgTemp(24,32)
# 0   34.577966
# 1   34.622807
# 2   34.543333
# 3   34.553333
# 4   34.550820
# ..        ...
# 95  34.572881
# 96  34.608197
# 97  34.710345
# 98  34.659322
# 99  34.665517
#
# [100 rows x 4 columns]

# %%
df_joao
# Out:
#                             file_name  AvgTemp(144,191)  AvgTemp(72,95)  \
# 0   thermal_20161122-14_09_37.471.txt  34.474038         34.458716
# 1   thermal_20161122-14_09_37.646.txt  34.454828         34.454174
# 2   thermal_20161122-14_09_37.718.txt  34.461408         34.456102
# 3   thermal_20161122-14_09_37.756.txt  34.474037         34.477656
# 4   thermal_20161122-14_09_37.791.txt  34.467482         34.465766
# ..                                ...        ...               ...
# 95  thermal_20161122-14_09_41.166.txt  34.523156         34.538530
# 96  thermal_20161122-14_09_41.201.txt  34.537173         34.535273
# 97  thermal_20161122-14_09_41.236.txt  34.550584         34.539750
# 98  thermal_20161122-14_09_41.276.txt  34.541973         34.515780
# 99  thermal_20161122-14_09_41.315.txt  34.537595         34.538959
#
#     AvgTemp(24,32)
# 0   34.577966
# 1   34.622807
# 2   34.543333
# 3   34.553333
# 4   34.550820
# ..        ...
# 95  34.572881
# 96  34.608197
# 97  34.710345
# 98  34.659322
# 99  34.665517
#
# [100 rows x 4 columns]

# %%
df_joao.dfi.export('df.png', max_rows = -1)
df_joao.export_png('df_styled.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-166-4220e5d15faa> in <module>
#       1 df_joao.dfi.export('df.png', max_rows = -1)
# ----> 2 df_joao.export_png('df_styled.png')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'export_png'

# %%
df_joao

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df_joao)

# %%
listOfStds = ['std(144,191)', 'std(72,95)', 'std(24,32)']

# %%
folder_avg_joao = []
joao_std = []
for idx,i in enumerate(df_joao.columns.values[1:]):
    folder_avg_joao.append({i : np.average(df_joao[i])})    
    joao_std.append({listOfStds[idx]: np.std(df_joao[i])})

# %%
joao_std

# %%
folder_avg_joao

# %% [markdown]
# ## Claudio df for 100 files with four down scales and average for each row at each size

# %%
os.chdir(r"C:\Users\hp\Videos\Step1-fixedDistance_avg,std\Folders\2016-11-22-14-23-08-Claudio_onlythermalthermal_image-txt")

# %%
claudio_files = []  #claudio 

for idx,file in enumerate(os.listdir()):
    with open(file)as f:
        text_file = np.loadtxt(f)
        
        cam_res1 = cv.resize(text_file, (191,144), interpolation = cv.INTER_NEAREST)
        cam_res1[cam_res1<32.0]=0
        cam_res1[cam_res1>37.0]=0
        #print(np.max(cam_res1), np.min(cam_res1[cam_res1 != 0 ]))
        
        
        cam_res2 = cv.resize(cam_res1, (95,72), interpolation = cv.INTER_NEAREST)
        cam_res3 = cv.resize(cam_res2, (32,24), interpolation = cv.INTER_NEAREST)
        #rint(np.max(cam_res3), np.min(cam_res3[cam_res3 != 0 ]))
        """"
        plt.imshow(text_file,cmap='jet')
        plt.show()
        plt.imshow(cam_res1,cmap='jet')
        plt.show()
        plt.imshow(cam_res2,cmap='jet')
        plt.show()
        plt.imshow(cam_res3,cmap='jet')
        plt.show()
        print()
        """
        
        claudio_files.append({"file_name":file,
                              "AvgTemp(144,191)": np.average(cam_res1[cam_res1 != 0]),
                              "AvgTemp(72,95)": np.average(cam_res2[cam_res2 != 0]),
                              "AvgTemp(24,32)": np.average(cam_res3[cam_res3 != 0])})
    if idx == 99:
        break

# %%
df_claudio = pd.DataFrame(claudio_files, columns = ['file_name',"AvgTemp(144,191)","AvgTemp(72,95)","AvgTemp(24,32)"])

# %%
df_claudio
# Out:
#                              file_name  AvgTemp(144,191)  AvgTemp(72,95)  \
# 0    thermal_20161122-14_23_09.024.txt  34.493566         34.535800
# 1    thermal_20161122-14_23_09.097.txt  34.514158         34.534911
# 2    thermal_20161122-14_23_09.135.txt  34.457150         34.476248
# 3    thermal_20161122-14_23_09.172.txt  34.468098         34.487475
# 4    thermal_20161122-14_23_09.210.txt  34.517483         34.527183
# ..                                 ...        ...               ...
# 96   thermal_20161122-14_23_12.620.txt  34.511578         34.498684
# 97   thermal_20161122-14_23_12.656.txt  34.511578         34.498684
# 98   thermal_20161122-14_23_12.692.txt  34.511578         34.498684
# 99   thermal_20161122-14_23_12.729.txt  34.511578         34.498684
# 100  thermal_20161122-14_23_12.767.txt  34.511578         34.498684
#
#      AvgTemp(24,32)
# 0    34.631481
# 1    34.637037
# 2    34.583019
# 3    34.521818
# 4    34.624074
# ..         ...
# 96   34.654386
# 97   34.654386
# 98   34.654386
# 99   34.654386
# 100  34.654386
#
# [101 rows x 4 columns]

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df_claudio)

# %%
listOfStds

# %%
folder_avg_claudio = []
claudio_std = []
for idx,i in enumerate(df_claudio.columns.values[1:]):
    folder_avg_claudio.append({i : np.average(df_claudio[i])})
    claudio_std.append({listOfStds[idx]: np.std(df_claudio[i])})

# %%
folder_avg_claudio

# %%
claudio_std

# %% [markdown]
# ### Anestis df for 100 files with four down scales and average for each row at each size

# %%
os.chdir(r"C:\Users\hp\Videos\Step1-fixedDistance_avg,std\Folders\2016-11-22-14-13-46-anestis_onlythermalthermal_image-txt")

# %%
anestis_files = []  #claudio 

for idx,file in enumerate(os.listdir()):
    with open(file)as f:
        text_file = np.loadtxt(f)
        
        cam_res1 = cv.resize(text_file, (191,144), interpolation = cv.INTER_NEAREST)
        cam_res1[cam_res1<32.0]=0
        cam_res1[cam_res1>37.0]=0
        #print(np.max(cam_res1), np.min(cam_res1[cam_res1 != 0 ]))
        
        
        cam_res2 = cv.resize(cam_res1, (95,72), interpolation = cv.INTER_NEAREST)
        cam_res3 = cv.resize(cam_res2, (32,24), interpolation = cv.INTER_NEAREST)
        #rint(np.max(cam_res3), np.min(cam_res3[cam_res3 != 0 ]))
        """"
        plt.imshow(text_file,cmap='jet')
        plt.show()
        plt.imshow(cam_res1,cmap='jet')
        plt.show()
        plt.imshow(cam_res2,cmap='jet')
        plt.show()
        plt.imshow(cam_res3,cmap='jet')
        plt.show()
        print()
        """
        
        
        anestis_files.append({"file_name":file,
                              "AvgTemp(144,191)": np.average(cam_res1[cam_res1 != 0]),
                              "AvgTemp(72,95)": np.average(cam_res2[cam_res2 != 0]),
                              "AvgTemp(24,32)": np.average(cam_res3[cam_res3 != 0])})
    if idx == 99:
        break

# %%
df_anestis = pd.DataFrame(anestis_files, columns = ['file_name',"AvgTemp(144,191)","AvgTemp(72,95)","AvgTemp(24,32)"])

# %%
df_anestis
# Out:
#                             file_name  AvgTemp(144,191)  AvgTemp(72,95)  \
# 80  34.378750
# 81  34.386250
# 82  34.406410
# 83  34.385000
# 84  34.419231
# 85  34.482051
# 86  34.380000
# 87  34.446835
# 88  34.395000
# 89  34.380000
# 90  34.403797
# 91  34.385000
# 92  34.413924
# 93  34.389744
# 94  34.343038
# 95  34.334177
# 96  34.327848
# 97  34.307595
# 98  34.262500
# 99  34.332000

# %%
anestis_avg_values = []

# %%
folder_avg_anestis = []
anestis_std = []
for idx,i in enumerate(df_anestis.columns.values[1:]):
    folder_avg_anestis.append({i : np.average(df_anestis[i])})
    anestis_std.append({listOfStds[idx]: np.std(df_anestis[i])})

# %%
anestis_std
# Out:
# [{'std(144,191)': 0.015419612529255826},
#  {'std(72,95)': 0.020030440028060644},
#  {'std(24,32)': 0.0826130079801894}]

# %% [markdown]
# ### Average per row for three folders at four different scales

# %%
pd.DataFrame({"Name": ['claudio','Joao','Anestis'],
             'AvgTemp(144,191)':[34.49785087067999,34.50989892068498,34.35012920387215]\
            , 'AvgTemp(72,95)':[34.500394847807605,34.50884268714953,34.3626544902959]\
            , 'AvgTemp(24,32)':[34.55686197967155,34.59467334822509,34.509298278088856]})
# Out:
#       Name  AvgTemp(144,191)  AvgTemp(72,95)  AvgTemp(24,32)
# 0  claudio  34.497851         34.500395       34.556862
# 1  Joao     34.509899         34.508843       34.594673
# 2  Anestis  34.350129         34.362654       34.509298

# %%
test = pd.DataFrame({"Name": ['claudio','Joao','Anestis'],
             'AvgTemp(144,191)':[34.49785087067999,34.50989892068498,34.35012920387215]\
            , 'AvgTemp(72,95)':[34.500394847807605,34.50884268714953,34.3626544902959]\
            , 'AvgTemp(24,32)':[34.55686197967155,34.59467334822509,34.509298278088856]})
test
# Out:
#       Name  AvgTemp(144,191)  AvgTemp(72,95)  AvgTemp(24,32)
# 0  claudio  34.497851         34.500395       34.556862
# 1  Joao     34.509899         34.508843       34.594673
# 2  Anestis  34.350129         34.362654       34.509298

# %%
test['std'] = np.std(test[['AvgTemp(144,191)','AvgTemp(72,95)','AvgTemp(24,32)']],axis=1)

# %%
test
# Out:
#       Name  AvgTemp(144,191)  AvgTemp(72,95)  AvgTemp(24,32)       std
# 0  claudio  34.497851         34.500395       34.556862       0.027238
# 1  Joao     34.509899         34.508843       34.594673       0.040214
# 2  Anestis  34.350129         34.362654       34.509298       0.072262

# %%
np.std([34.497851, 34.500395, 34.556862])
# Out:
# 0.027238233231171336

# %% [markdown]
# ### Standard deviation for three folders at four different scales

# %%
pd.DataFrame({"Name":
              ['claudio','Joao','Anestis']
            , 'std(144,191)':[0.01886000410442223, 0.018540647118231956,0.015371547305321627]\
            , 'std(72,95)':[0.028265353490643932, 0.024646379041047137, 0.019958006175345336 ]\
            , 'std(24,32)':[0.08999542765363515, 0.06283265046011105, 0.08263072582103158]})
# Out:
#       Name  std(144,191)  std(72,95)  std(24,32)
# 0  claudio  0.018860      0.028265    0.089995
# 1  Joao     0.018541      0.024646    0.062833
# 2  Anestis  0.015372      0.019958    0.082631
